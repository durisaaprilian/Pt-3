# %% [markdown]
# # Jobsheet 02 - Regression
#
# NIM : 2241727022<br>
# Nama : Mohammad Durisa Enama Aprilian<br>
# Kelas : 4J

# %%
# import package
import numpy as np
import pandas as pd

# %%
#baca data
data = pd.read_csv('GDP_table.csv')
data.head()
# Out:
#    year       Belgium         France        Germany          Italy  \
# 0  2017  502764720556  2595151045198  3690849152518  1961796197354
# 1  2018  543347368038  2790956878747  3977289455388  2091932426267
# 2  2019  535376258147  2728870246706  3888326788627  2011285742552
# 3  2020  521676942135  2630317731455  3846413928654  1892574064222
# 4  2021  599879025378  2937472757953  4223116205969  2099880198259
#
#          Poland          Spain
# 0  526508877305  1312539279462
# 1  587411745162  1420994142512
# 2  597280564672  1393046093137
# 3  596624355720  1281484640044
# 4  674048266397  1425276586283

# %%
# pemahaman terhadap data
# ukuran data
data.shape

# info data
data.info()

# deskripsi data
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     5 non-null      int64
#  1   Belgium  5 non-null      int64
#  2   France   5 non-null      int64
#  3   Germany  5 non-null      int64
#  4   Italy    5 non-null      int64
#  5   Poland   5 non-null      int64
#  6   Spain    5 non-null      int64
# dtypes: int64(7)
# memory usage: 408.0 bytes
#               year       Belgium        France       Germany         Italy  \
# count     5.000000  5.000000e+00  5.000000e+00  5.000000e+00  5.000000e+00
# mean   2019.000000  5.406089e+11  2.736554e+12  3.925199e+12  2.011494e+12
# std       1.581139  3.653227e+10  1.366272e+11  1.961852e+11  8.788391e+10
# min    2017.000000  5.027647e+11  2.595151e+12  3.690849e+12  1.892574e+12
# 25%    2018.000000  5.216769e+11  2.630318e+12  3.846414e+12  1.961796e+12
# 50%    2019.000000  5.353763e+11  2.728870e+12  3.888327e+12  2.011286e+12
# 75%    2020.000000  5.433474e+11  2.790957e+12  3.977289e+12  2.091932e+12
# max    2021.000000  5.998790e+11  2.937473e+12  4.223116e+12  2.099880e+12
#
#              Poland         Spain
# count  5.000000e+00  5.000000e+00
# mean   5.963748e+11  1.366668e+12
# std    5.243003e+10  6.570431e+10
# min    5.265089e+11  1.281485e+12
# 25%    5.874117e+11  1.312539e+12
# 50%    5.966244e+11  1.393046e+12
# 75%    5.972806e+11  1.420994e+12
# max    6.740483e+11  1.425277e+12

# %%
# import library untuk visualisasi
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# operasi visualisasi
sns.pairplot(data, x_vars=['Belgium', 'France','Germany','Italy','Poland','Spain'], 
             y_vars='year', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
# Buat variabel bebas X dan Y, sebagai contoh ambil dari hasil analisis korelasi dari kegaitan sebelumnya
X = data['Belgium']
y = data['year']

# %%
# Buat pemisahan data uji dan data latih dengan proporsi 7:3
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, 
                                                    test_size = 0.3, random_state = 100)

# %%
# hasil training dtaset
X_train
y_train
# Out:
# 3    2020
# 4    2021
# 0    2017
# Name: year, dtype: int64

# %%
# training model
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train)

# %%
# visualisasi garis regresi
plt.scatter(X_train, y_train)
plt.plot(X_train, 265.2483 + 66.3015*X_train, 'r')
plt.show()
